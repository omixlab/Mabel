# %%
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json
import requests
import urllib 
import requests
from json import loads
import pandas as pd

# %%
url = f"http://api.elsevier.com/content/search/scopus?query=KEY{keyword}"

# Make a request for a given paper
resp = requests.get(url,
                    headers = {'Accept': 'application/json',
                               'X-ELS-APIKey': apikey,
                               'X-RateLimit-Reset': None})
 
# Check the status of the request
print(resp.status_code)

# Check if the problem is the weekly download limit (usually 10000)
try:
    print(resp.header['X-RateLimit-Remaining'])
except:
    pass
# Out:
# 200

# %%
dic = loads(resp.content)

print(type(dic))

data = pd.DataFrame.from_dict(dic)
# Out:
# <class 'dict'>

# %%
pd.DataFrame(data.iloc[0])
# Out:
#                                                             entry
# search-results  [{'@_fa': 'true', 'link': [{'@_fa': 'true', '@...

# %%
for i in data.iloc[0]:
    scopus_data = pd.DataFrame(i)

# %%
scopus_data
# Out:
#     @_fa                                               link  \
# 0   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 3   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 4   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 5   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 6   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 7   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 8   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 9   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 10  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 11  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 12  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 13  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 14  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 15  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 16  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 17  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 18  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 19  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 20  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 21  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 22  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 23  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 24  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                             prism:url          dc:identifier  \
# 0   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85153237853
# 1   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85153034116
# 2   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85152671400
# 3   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85152562636
# 4   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85152299933
# 5   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85151474819
# 6   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85151328922
# 7   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85151110394
# 8   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150956328
# 9   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150922579
# 10  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150870210
# 11  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150393802
# 12  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150316676
# 13  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150283003
# 14  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150246447
# 15  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150216818
# 16  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85150153292
# 17  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85149987223
# 18  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85149912483
# 19  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85149582829
# 20  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85149549875
# 21  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85149530385
# 22  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85148766938
# 23  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85148749777
# 24  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85147977139
#
#                    eid                                           dc:title  \
# 0   2-s2.0-85153237853  Novel insights into the multifaceted roles of ...
# 1   2-s2.0-85153034116  Cancer immunotherapy with immune checkpoint in...
# 2   2-s2.0-85152671400  Efficacy and safety of catheter ablation for a...
# 3   2-s2.0-85152562636  Co-expression and clinical utility of AR-FL an...
# 4   2-s2.0-85152299933  Targeting advanced prostate cancer with STEAP1...
# 5   2-s2.0-85151474819  In vivo imaging of prostate tumor-targeted fol...
# 6   2-s2.0-85151328922  TRABID overexpression enables synthetic lethal...
# 7   2-s2.0-85151110394  ORC6, a novel prognostic biomarker, correlates...
# 8   2-s2.0-85150956328  The function and mechanisms of action of circu...
# 9   2-s2.0-85150922579  Tolerability of concurrent external beam radio...
# 10  2-s2.0-85150870210  The nerve growth factor-delivered signals in p...
# 11  2-s2.0-85150393802  Involvement of inflammasomes in tumor microenv...
# 12  2-s2.0-85150316676  Engineered exosomes from different sources for...
# 13  2-s2.0-85150283003  Tumor immune contexture predicts recurrence af...
# 14  2-s2.0-85150246447  Research progress on non-protein-targeted drug...
# 15  2-s2.0-85150216818  Beyond diagnosis: is there a role for radiomic...
# 16  2-s2.0-85150153292  Tumor cell plasticity in targeted therapy-indu...
# 17  2-s2.0-85149987223  Extracellular matrix remodeling in tumor progr...
# 18  2-s2.0-85149912483  CD46 targeted <sup>212</sup>Pb alpha particle ...
# 19  2-s2.0-85149582829  The epigenetic regulatory mechanism of PIWI/pi...
# 20  2-s2.0-85149549875  Heterogeneous uptake of <sup>18</sup>F-FDG and...
# 21  2-s2.0-85149530385  Emerging phagocytosis checkpoints in cancer im...
# 22  2-s2.0-85148766938  MicroRNA-122 in human cancers: from mechanisti...
# 23  2-s2.0-85148749777  Emerging roles of m6A RNA modification in canc...
# 24  2-s2.0-85147977139  Investigation of image-based lesion and kidney...
#
#                dc:creator                              prism:publicationName  \
# 0                 Tang J.                                 Biomarker Research
# 1              Marei H.E.                          Cancer Cell International
# 2              Ganatra S.                                    Cardio-Oncology
# 3             Wüstmann N.                                 Biomarker Research
# 4               Bhatia V.                              Nature Communications
# 5               Pandey S.                              Cancer Nanotechnology
# 6                   Ma J.                              Nature Communications
# 7                  Lin Y.                                         BMC Cancer
# 8              Zhang Z.h.                                   Molecular Cancer
# 9      van der Sar E.C.A.                                         BMC Cancer
# 10           Di Donato M.                                Cell and Bioscience
# 11               Zhang Z.                 Journal of Hematology and Oncology
# 12               Zhang M.           Signal Transduction and Targeted Therapy
# 13                 Han S.                  Journal of Translational Medicine
# 14               Zhang Y.  Journal of Experimental and Clinical Cancer Re...
# 15           Stanzione A.                    European Radiology Experimental
# 16               Shi Z.D.           Signal Transduction and Targeted Therapy
# 17                Yuan Z.                                   Molecular Cancer
# 18                  Li J.  Journal of Experimental and Clinical Cancer Re...
# 19               Zhang Q.                                   Molecular Cancer
# 20                  Hu Y.                             BMC Pulmonary Medicine
# 21                 Liu Y.           Signal Transduction and Targeted Therapy
# 22  Faramin Lashkarian M.                          Cancer Cell International
# 23               Liu W.W.               Experimental Hematology and Oncology
# 24               Resch S.                                     EJNMMI Physics
#
#    prism:eIssn prism:volume  ... subtype subtypeDescription article-number  \
# 0     20507771           11  ...      re             Review             42
# 1     14752867           23  ...      re             Review             64
# 2     20573804            9  ...      ar            Article             19
# 3     20507771           11  ...      ar            Article             37
# 4     20411723           14  ...      ar            Article           2041
# 5     18686966           14  ...      ar            Article             30
# 6     20411723           14  ...      ar            Article           1810
# 7     14712407           23  ...      ar            Article            285
# 8     14764598           22  ...      re             Review             61
# 9     14712407           23  ...      ar            Article            268
# 10    20453701           13  ...      re             Review             60
# 11    17568722           16  ...      re             Review             24
# 12    20593635            8  ...      re             Review            124
# 13    14795876           21  ...      ar            Article            194
# 14    17569966           42  ...      re             Review             62
# 15    25099280            7  ...      ar            Article             13
# 16    20593635            8  ...      re             Review            113
# 17    14764598           22  ...      re             Review             48
# 18    17569966           42  ...      ar            Article             61
# 19    14764598           22  ...      re             Review             45
# 20    14712466           23  ...      ar            Article             73
# 21    20593635            8  ...      re             Review            104
# 22    14752867           23  ...      re             Review             29
# 23    21623619           12  ...      re             Review             21
# 24    21977364           10  ...      ar            Article             11
#
#       source-id openaccess openaccessFlag  \
# 0   21100853949          1           True
# 1         29094          1           True
# 2   21101059717          1           True
# 3   21100853949          1           True
# 4   19700182758          1           True
# 5   19700173005          1           True
# 6   19700182758          1           True
# 7         28747          1           True
# 8         12429          1           True
# 9         28747          1           True
# 10  19900193985          1           True
# 11  17900156736          1           True
# 12  21100888816          1           True
# 13        16440          1           True
# 14        29951          1           True
# 15  21100904743          1           True
# 16  21100888816          1           True
# 17        12429          0          False
# 18        29951          0          False
# 19        12429          1           True
# 20        18026          0          False
# 21  21100888816          1           True
# 22        29094          1           True
# 23  21100459104          1           True
# 24  21100440520          1           True
#
#                                            freetoread  \
# 0   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 1   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 2   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 3   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 4   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 5   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 6                                                 NaN
# 7   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 8   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 9   {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 10  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 11  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 12  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 13  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 14  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 15  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 16  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 17                                                NaN
# 18                                                NaN
# 19  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 20                                                NaN
# 21  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 22  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
# 23                                                NaN
# 24  {'value': [{'$': 'all'}, {'$': 'publisherfullg...
#
#                                       freetoreadLabel pubmed-id prism:issn
# 0   {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
# 1   {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
# 2   {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
# 3   {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
# 4   {'value': [{'$': 'All Open Access'}, {'$': 'Go...  37041154        NaN
# 5   {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN   18686958
# 6                                                 NaN  37002234        NaN
# 7   {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36978046        NaN
# 8   {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36966306        NaN
# 9   {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36959540        NaN
# 10  {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
# 11  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36932407        NaN
# 12  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36922504   20959907
# 13  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36918939        NaN
# 14  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36918935        NaN
# 15  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36907973        NaN
# 16  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36906600   20959907
# 17                                                NaN  36906534        NaN
# 18                                                NaN  36906664        NaN
# 19  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36882835        NaN
# 20                                                NaN  36882747        NaN
# 21  {'value': [{'$': 'All Open Access'}, {'$': 'Go...  36882399   20959907
# 22  {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
# 23                                                NaN       NaN        NaN
# 24  {'value': [{'$': 'All Open Access'}, {'$': 'Go...       NaN        NaN
#
# [25 rows x 28 columns]
