# %%
import pandas as pd
import numpy as np

# %%
formated_dfs = []

scopus = pd.read_csv("scopus.csv")
scopus.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Metabotropic glutamate receptor 5 (mGluR5) is ...
# 1           1  Brain-targeted delivery of neuroprotective sur...
# 2           2  Associations between genetically predicted pla...
# 3           3  Network-based identification and mechanism exp...
# 4           4  Death-associated protein kinase 1 as a therape...
#
#                                             Abstract    Pages  \
# 0  Background: Metabotropic glutamate receptor 5 ...      NaN
# 1  Background: Neurodegenerative diseases, includ...      NaN
# 2  Background: Specific peripheral proteins have ...      NaN
# 3  Alzheimer's disease is a neurodegenerative dis...  506-519
# 4  Alzheimer’s disease (AD) is the most prevalent...      NaN
#
#                                              Journal   Authors        Date  \
# 0                   Alzheimer's Research and Therapy   Wang J.  2024-12-01
# ...

# %%
total = len(scopus)
print('Total:', total)
scopus.drop_duplicates(subset=['DOI'])
dropped = len(scopus)

print('Dropped:', total-dropped)
print(len(scopus))
# Out:
# Total: 7800
# Dropped: 0
# 7800
