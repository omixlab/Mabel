# %%
# prompt: instalar  en_core_web_sm via pip 
#!pip install scispacy
#pip install flair==0.14
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz (15.9 MB)
#   Preparing metadata (setup.py) ... done
# Collecting spacy<3.5.0,>=3.4.1 (from en_core_sci_sm==0.5.1)
#   Using cached spacy-3.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.0.10)
# Collecting thinc<8.2.0,>=8.1.0 (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1)
#   Using cached thinc-8.1.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.1.0,>=0.9.1 (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1)
#   Using cached wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (2.0.10)
# Collecting typer<0.8.0,>=0.3.0 (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1)
#   Using cached typer-0.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting pathy>=0.3.5 (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1)
#   Using cached pathy-0.11.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (2.32.4)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1)
#   Using cached pydantic-1.10.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (154 kB)
# Requirement already satisfied: jinja2 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.1.6)
# Requirement already satisfied: setuptools in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (78.1.1)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (2025.7.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (8.2.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (1.2.1)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.3.5->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1)
#   Using cached pathlib_abc-0.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniconda3/envs/BioSyn/lib/python3.11/site-packages (from jinja2->spacy<3.5.0,>=3.4.1->en_core_sci_sm==0.5.1) (3.0.2)
# Using cached spacy-3.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
# Using cached pydantic-1.10.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached thinc-8.1.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (917 kB)
# Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Using cached pathy-0.11.0-py3-none-any.whl (47 kB)
# Using cached pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Building wheels for collected packages: en_core_sci_sm
#   DEPRECATION: Building 'en_core_sci_sm' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'en_core_sci_sm'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for en_core_sci_sm (setup.py) ... done
#   Created wheel for en_core_sci_sm: filename=en_core_sci_sm-0.5.1-py3-none-any.whl size=15870888 sha256=62cecd8989df79e17498e8dfc40cee816e510e3ce6a7a8c493e923f6ad087e28
#   Stored in directory: /home/grati/.cache/pip/wheels/f0/4d/eb/0d4f64bca5fb19915b27acb2aaab5391404b0f76092d41d96d
# Successfully built en_core_sci_sm
# Installing collected packages: wasabi, typer, pydantic, pathlib-abc, pathy, thinc, spacy, en_core_sci_sm
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.7
#     Uninstalling pydantic-2.11.7:
#       Successfully uninstalled pydantic-2.11.7
#   Attempting uninstall: thinc━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [pydantic]
#     Found existing installation: thinc 8.2.5━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [pydantic]
#     Uninstalling thinc-8.2.5:0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [pydantic]
#       Successfully uninstalled thinc-8.2.5╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [pydantic]
#   Attempting uninstall: spacy━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 5/8 [thinc]
#     Found existing installation: spacy 3.7.20m╺━━━━━━━━━━━━━━ 5/8 [thinc]
#     Uninstalling spacy-3.7.2:━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 6/8 [spacy]
#       Successfully uninstalled spacy-3.7.2━━━━━╺━━━━━━━━━ 6/8 [spacy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [en_core_sci_sm] 7/8 [en_core_sci_sm]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scispacy 0.5.5 requires spacy<3.8.0,>=3.7.0, but you have spacy 3.4.4 which is incompatible.
# Successfully installed en_core_sci_sm-0.5.1 pathlib-abc-0.1.1 pathy-0.11.0 pydantic-1.10.22 spacy-3.4.4 thinc-8.1.12 typer-0.7.0 wasabi-0.10.1

# %%
from flair.data import Sentence
from flair.models import EntityMentionLinker
from flair.nn import Classifier
from flair.tokenization import SciSpacyTokenizer

sentence = Sentence(
    "The mutation in the ABCD1 gene causes X-linked adrenoleukodystrophy, "
    "a neurodegenerative disease, which is exacerbated by exposure to high "
    "levels of mercury in dolphin populations.",
    use_tokenizer=SciSpacyTokenizer()
)

# load hunflair to detect the entity mentions we want to link.
tagger = Classifier.load("hunflair2")
tagger.predict(sentence)

# load the linker and dictionary
linker = EntityMentionLinker.load("gene-linker")
linker.predict(sentence)

# print the results for each entity mention:
for span in sentence.get_spans(tagger.label_type):
    for link in span.get_labels(linker.label_type):
      print(f"{span.text} -> {link.value}")
# Out:
# /home/grati/miniconda3/envs/BioSyn/lib/python3.11/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_sci_sm' (0.5.1) was trained with spaCy v3.4.1 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# 2025-07-20 23:43:44,029 --------------------------------------------------------------------------------
# 2025-07-20 23:43:44,035 ERROR: The key 'hunflair2' was neither found on the ModelHub nor is this a valid path to a file on your system!
# 2025-07-20 23:43:44,040  -> Please check https://huggingface.co/models?filter=flair for all available models.
# 2025-07-20 23:43:44,043  -> Alternatively, point to a model file on your local drive.
# 2025-07-20 23:43:44,049 --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/nn/model.py:155, in Model.load(cls, model_path)
#     154 try:
# --> 155     state = model_path if isinstance(model_path, dict) else load_torch_state(str(model_path))
#     156 except Exception:
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/file_utils.py:383, in load_torch_state(model_file)
#     380 # load_big_file is a workaround byhttps://github.com/highway11git
#     381 # to load models on some Mac/Windows setups
#     382 # see https://github.com/zalandoresearch/flair/issues/351
# --> 383 f = load_big_file(model_file)
#     384 return torch.load(f, map_location="cpu")
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/file_utils.py:51, in load_big_file(f)
#      47 """Workaround for loading a big pickle file.
#      48
#      49 Files over 2GB cause pickle errors on certain Mac and Windows distributions.
#      50 """
# ---> 51 with open(f, "rb") as f_in:
#      52     # mmap seems to be much more memory efficient
#      53     bf = mmap.mmap(f_in.fileno(), 0, access=mmap.ACCESS_READ)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hunflair2'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 14
#       6 sentence = Sentence(
#       7     "The mutation in the ABCD1 gene causes X-linked adrenoleukodystrophy, "
#       8     "a neurodegenerative disease, which is exacerbated by exposure to high "
#       9     "levels of mercury in dolphin populations.",
#      10     use_tokenizer=SciSpacyTokenizer()
#      11 )
#      13 # load hunflair to detect the entity mentions we want to link.
# ---> 14 tagger = Classifier.load("hunflair2")
#      15 tagger.predict(sentence)
#      17 # load the linker and dictionary
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/nn/model.py:564, in Classifier.load(cls, model_path)
#     560 @classmethod
#     561 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "Classifier":
#     562     from typing import cast
# --> 564     return cast("Classifier", super().load(model_path=model_path))
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/nn/model.py:164, in Model.load(cls, model_path)
#     162     log.error(" -> Alternatively, point to a model file on your local drive.")
#     163     log.error("-" * 80)
# --> 164     raise ValueError(f"Could not find any model with name '{model_path}'")
#     166 # try to get model class from state
#     167 cls_name = state.pop("__cls__", None)
#
# ValueError: Could not find any model with name 'hunflair2'

# %%
tagger = Classifier.load("hunflair")
# Out:
# 2025-07-20 23:48:45,619 HunFlair (version 1) is deprecated. Consider using HunFlair2 for improved extraction performance: Classifier.load('hunflair2').See https://github.com/flairNLP/flair/blob/master/resources/docs/HUNFLAIR2.md for further information.
# 2025-07-20 23:48:46,621 https://nlp.informatik.hu-berlin.de/resources/models/bioner/hunflair.pt not found in cache, downloading to /tmp/tmpup1mr42l
# 100%|██████████████████████████████████████| 1.41G/1.41G [04:58<00:00, 5.09MB/s]
# 2025-07-20 23:53:45,513 copying /tmp/tmpup1mr42l to cache at /home/grati/.flair/models/hunflair.pt
# 2025-07-20 23:53:52,178 removing temp file /tmp/tmpup1mr42l
# 2025-07-20 23:53:53,058 --------------------------------------------------------------------------------
# 2025-07-20 23:53:53,059 ERROR: The key 'hunflair' was neither found on the ModelHub nor is this a valid path to a file on your system!
# 2025-07-20 23:53:53,060  -> Please check https://huggingface.co/models?filter=flair for all available models.
# 2025-07-20 23:53:53,061  -> Alternatively, point to a model file on your local drive.
# 2025-07-20 23:53:53,062 --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/nn/model.py:155, in Model.load(cls, model_path)
#     154 try:
# --> 155     state = model_path if isinstance(model_path, dict) else load_torch_state(str(model_path))
#     156 except Exception:
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/file_utils.py:383, in load_torch_state(model_file)
#     380 # load_big_file is a workaround byhttps://github.com/highway11git
#     381 # to load models on some Mac/Windows setups
#     382 # see https://github.com/zalandoresearch/flair/issues/351
# --> 383 f = load_big_file(model_file)
#     384 return torch.load(f, map_location="cpu")
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/file_utils.py:51, in load_big_file(f)
#      47 """Workaround for loading a big pickle file.
#      48
#      49 Files over 2GB cause pickle errors on certain Mac and Windows distributions.
#      50 """
# ---> 51 with open(f, "rb") as f_in:
#      52     # mmap seems to be much more memory efficient
#      53     bf = mmap.mmap(f_in.fileno(), 0, access=mmap.ACCESS_READ)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hunflair'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tagger = Classifier.load("hunflair")
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/nn/model.py:564, in Classifier.load(cls, model_path)
#     560 @classmethod
#     561 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "Classifier":
#     562     from typing import cast
# --> 564     return cast("Classifier", super().load(model_path=model_path))
#
# File ~/miniconda3/envs/BioSyn/lib/python3.11/site-packages/flair/nn/model.py:164, in Model.load(cls, model_path)
#     162     log.error(" -> Alternatively, point to a model file on your local drive.")
#     163     log.error("-" * 80)
# --> 164     raise ValueError(f"Could not find any model with name '{model_path}'")
#     166 # try to get model class from state
#     167 cls_name = state.pop("__cls__", None)
#
# ValueError: Could not find any model with name 'hunflair'

# %%
gene_linker = EntityMentionLinker.load("gene-linker")
gene_linker.predict(sentence)
